# %% [markdown]
# # Data Set Construction

# %% [markdown]
# In this notebook we contruct the database of all regular season NBA games from 2016-17 to 2018-19 season. We obtain the following variables:
#
# - *Target*
#  - Combined score (TOT_PTS)
# - *Features*
#  - Number of days between games (DAYS_BTWN_GAMES_x, DAYS_BTWN_GAMES_y)
#  - Number of wins in last 10 games (WINS_10GAMES_x, WINS_10GAMES_y)
#  - Wins thus far in the season (WINS_UPTOGAME_x, WINS_UPTOGAME_y)
#  - Combined points in previous matchup (pre_PTS)
#  - Distance traveled (distance_miles)
#  - Rivalry (rivalry)
#  - Avg. points/team in last 2,3 and 4 games (AVGPOINTS_2GAMES_x,...AVGPOINTS_4GAMES_y)
#  - Referees (not used in analysis)

# %%
import pandas as pd
import numpy as np
import requests
import nba_api
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.endpoints import boxscoresummaryv2

# %%
# Get basic game info for 2016-2019 NBA seasons, regular seasons only

gamefinder_1 = leaguegamefinder.LeagueGameFinder(
    season_nullable='2016-17',
    season_type_nullable='Regular Season',
    league_id_nullable='00')
games_1 = gamefinder_1.get_data_frames()[0]

gamefinder_2 = leaguegamefinder.LeagueGameFinder(
    season_nullable='2017-18',
    season_type_nullable='Regular Season',
    league_id_nullable='00')
games_2 = gamefinder_2.get_data_frames()[0]

gamefinder_3 = leaguegamefinder.LeagueGameFinder(
    season_nullable='2018-19',
    season_type_nullable='Regular Season',
    league_id_nullable='00')
games_3 = gamefinder_3.get_data_frames()[0]

# %%
#Combine datasets so all three seasons are in one dataset
games = games_1.append([games_2,games_3])

# %%
#Remove variables we don't need & make game date into date format
games = games.drop(columns=['MIN','FGM','FGA','FG_PCT','FG3M','FG3A','FG3_PCT','FTM','FTA','FT_PCT','OREB','DREB','REB','AST','STL','BLK','TOV','PF','PLUS_MINUS'])
games['GAME_DATE'] = pd.to_datetime(games.GAME_DATE)

# %%
#Calculate whether there are back-to-back games

#Sort by team & game date
games = games.sort_values(by=['SEASON_ID','TEAM_ID','GAME_DATE'], ascending=True)

#Calculate number of days between games
#Note: the sort above must be done before this command or it will be wrong
games['DAYS_BTWN_GAMES'] = games.groupby(['SEASON_ID','TEAM_ID'])['GAME_DATE'].diff() / np.timedelta64(1, 'D') 
games['DAYS_BTWN_GAMES'] = games['DAYS_BTWN_GAMES'].fillna(0)

# %%
games.head()
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION      TEAM_NAME     GAME_ID  \
# 2428     22016  1610612737               ATL  Atlanta Hawks  0021600014
# 2395     22016  1610612737               ATL  Atlanta Hawks  0021600026
# 2375     22016  1610612737               ATL  Atlanta Hawks  0021600044
# 2350     22016  1610612737               ATL  Atlanta Hawks  0021600059
# 2319     22016  1610612737               ATL  Atlanta Hawks  0021600070
#
#       GAME_DATE      MATCHUP WL  PTS  DAYS_BTWN_GAMES
# 2428 2016-10-27  ATL vs. WAS  W  114              0.0
# 2395 2016-10-29    ATL @ PHI  W  104              2.0
# 2375 2016-10-31  ATL vs. SAC  W  106              2.0
# 2350 2016-11-02  ATL vs. LAL  L  116              2.0
# 2319 2016-11-04    ATL @ WAS  L   92              2.0

# %%
# Calculate the team's number of wins in the last 10 games

# Generate dummy variable from WL variable
dummy = pd.get_dummies(games['WL'])
games = pd.concat([games, dummy], axis=1)
games.head()

#Sort by team & game date
games = games.sort_values(by=['SEASON_ID','TEAM_ID','GAME_DATE'], ascending=True)

# Calculate number of wins over last ten games
f = lambda x: x.rolling(min_periods=1, window=10).sum().shift()

games1 = games.groupby(['SEASON_ID','TEAM_ID','GAME_DATE'], as_index=False)['W'].sum()
games1['WINS_10GAMES'] = games1.groupby(['SEASON_ID','TEAM_ID'])['W'].apply(f).reset_index(drop=True, level=0)
games1['WINS_10GAMES'] = games1['WINS_10GAMES'].fillna(0) 

games = pd.merge(games,games1[['SEASON_ID','TEAM_ID','GAME_DATE','WINS_10GAMES']],on=['SEASON_ID','TEAM_ID','GAME_DATE'], how='left')

# %%
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION      TEAM_NAME     GAME_ID  \
# 0     22016  1610612737               ATL  Atlanta Hawks  0021600014
# 1     22016  1610612737               ATL  Atlanta Hawks  0021600026
# 2     22016  1610612737               ATL  Atlanta Hawks  0021600044
# 3     22016  1610612737               ATL  Atlanta Hawks  0021600059
# 4     22016  1610612737               ATL  Atlanta Hawks  0021600070
#
#    GAME_DATE      MATCHUP WL  PTS  DAYS_BTWN_GAMES  L  W  WINS_10GAMES
# 0 2016-10-27  ATL vs. WAS  W  114              0.0  0  1           0.0
# 1 2016-10-29    ATL @ PHI  W  104              2.0  0  1           1.0
# 2 2016-10-31  ATL vs. SAC  W  106              2.0  0  1           2.0
# 3 2016-11-02  ATL vs. LAL  L  116              2.0  1  0           3.0
# 4 2016-11-04    ATL @ WAS  L   92              2.0  1  0           3.0

# %%
# Calculate the team's number of wins thus far in the season

#Sort by team & game date
games = games.sort_values(by=['SEASON_ID','TEAM_ID','GAME_DATE'], ascending=True)

# Calculate number of wins over season so far
f = lambda x: x.rolling(min_periods=1, window=82).sum().shift()

games1 = games.groupby(['SEASON_ID','TEAM_ID','GAME_DATE'], as_index=False)['W'].sum()
games1['WINS_UPTOGAME'] = games1.groupby(['SEASON_ID','TEAM_ID'])['W'].apply(f).reset_index(drop=True, level=0)
games1['WINS_UPTOGAME'] = games1['WINS_UPTOGAME'].fillna(0) 

games = pd.merge(games,games1[['SEASON_ID','TEAM_ID','GAME_DATE','WINS_UPTOGAME']],on=['SEASON_ID','TEAM_ID','GAME_DATE'], how='left')

#drop win/loss dummy
games = games.drop(columns=['W','L'])

games.head(50)
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION      TEAM_NAME     GAME_ID  \
# 0      22016  1610612737               ATL  Atlanta Hawks  0021600014
# 1      22016  1610612737               ATL  Atlanta Hawks  0021600026
# 2      22016  1610612737               ATL  Atlanta Hawks  0021600044
# 3      22016  1610612737               ATL  Atlanta Hawks  0021600059
# 4      22016  1610612737               ATL  Atlanta Hawks  0021600070
# 5      22016  1610612737               ATL  Atlanta Hawks  0021600084
# 6      22016  1610612737               ATL  Atlanta Hawks  0021600100
# 7      22016  1610612737               ATL  Atlanta Hawks  0021600111
# 8      22016  1610612737               ATL  Atlanta Hawks  0021600132
# 9      22016  1610612737               ATL  Atlanta Hawks  0021600154
# 10     22016  1610612737               ATL  Atlanta Hawks  0021600163
# 22           10.0
# 23           11.0
# 24           12.0
# 25           12.0
# 26           13.0
# 27           13.0
# 28           14.0
# 29           14.0
# 30           15.0
# 31           15.0
# 32           16.0
# 33           17.0
# 34           18.0
# 35           19.0
# 36           20.0
# 37           21.0
# 38           22.0
# 39           22.0
# 40           23.0
# 41           24.0
# 42           24.0
# 43           25.0
# 44           26.0
# 45           26.0
# 46           27.0
# 47           27.0
# 48           28.0
# 49           28.0

# %%
#Calculate average points per team over last j days (within the current season)
#Note: if there are fewer than j days, just give the average points in 

#Sort by team & game date
games = games.sort_values(by=['SEASON_ID','TEAM_ID','GAME_DATE'], ascending=True)

# Calculate average points over last two games
for j in range(2,5,1):
    f = lambda x: x.rolling(min_periods=1, window=j).mean().shift()

    games1 = games.groupby(['SEASON_ID','TEAM_ID','GAME_DATE'], as_index=False)['PTS'].mean()
    games1['AVGPOINTS_'+str(j)+'GAMES'] = games1.groupby(['SEASON_ID','TEAM_ID'])['PTS'].apply(f).reset_index(drop=True, level=0)
    games = pd.merge(games,games1[['SEASON_ID','TEAM_ID','GAME_DATE','AVGPOINTS_'+str(j)+'GAMES']],on=['SEASON_ID','TEAM_ID','GAME_DATE'], how='left')

games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION      TEAM_NAME     GAME_ID  \
# 0     22016  1610612737               ATL  Atlanta Hawks  0021600014
# 1     22016  1610612737               ATL  Atlanta Hawks  0021600026
# 2     22016  1610612737               ATL  Atlanta Hawks  0021600044
# 3     22016  1610612737               ATL  Atlanta Hawks  0021600059
# 4     22016  1610612737               ATL  Atlanta Hawks  0021600070
#
#    GAME_DATE      MATCHUP WL  PTS  DAYS_BTWN_GAMES  WINS_10GAMES  \
# 0 2016-10-27  ATL vs. WAS  W  114              0.0           0.0
# 1 2016-10-29    ATL @ PHI  W  104              2.0           1.0
# 2 2016-10-31  ATL vs. SAC  W  106              2.0           2.0
# 3 2016-11-02  ATL vs. LAL  L  116              2.0           3.0
# 4 2016-11-04    ATL @ WAS  L   92              2.0           3.0
#
#    WINS_UPTOGAME  AVGPOINTS_2GAMES  AVGPOINTS_3GAMES  AVGPOINTS_4GAMES
# 0            0.0               NaN               NaN               NaN
# 1            1.0             114.0        114.000000             114.0
# 2            2.0             109.0        109.000000             109.0
# 3            3.0             105.0        108.000000             108.0
# 4            3.0             111.0        108.666667             110.0

# %%
#Combine two rows into one so unit of observation is game
gamelvl_df = pd.merge(games, games, on=['SEASON_ID', 'GAME_ID', 'GAME_DATE'])
gamelvl_df = gamelvl_df.loc[~(gamelvl_df['TEAM_ID_x']==gamelvl_df['TEAM_ID_y'])]

#Keep away team as team "x" and home team as team "y"
gamelvl_df = gamelvl_df[gamelvl_df.MATCHUP_x.str.contains(' @ ')]

# %%
gamelvl_df.head()
# Out:
#    SEASON_ID   TEAM_ID_x TEAM_ABBREVIATION_x         TEAM_NAME_x     GAME_ID  \
# 2      22016  1610612764                 WAS  Washington Wizards  0021600014
# 5      22016  1610612737                 ATL       Atlanta Hawks  0021600026
# 10     22016  1610612758                 SAC    Sacramento Kings  0021600044
# 14     22016  1610612747                 LAL  Los Angeles Lakers  0021600059
# 17     22016  1610612737                 ATL       Atlanta Hawks  0021600070
#
#     GAME_DATE  MATCHUP_x WL_x  PTS_x  DAYS_BTWN_GAMES_x  ...  \
# 2  2016-10-27  WAS @ ATL    L     99                0.0  ...
# 5  2016-10-29  ATL @ PHI    W    104                2.0  ...
# 10 2016-10-31  SAC @ ATL    L     95                2.0  ...
# 14 2016-11-02  LAL @ ATL    W    123                1.0  ...
# 17 2016-11-04  ATL @ WAS    L     92                2.0  ...
#
#            TEAM_NAME_y    MATCHUP_y  WL_y  PTS_y  DAYS_BTWN_GAMES_y  \
# 2        Atlanta Hawks  ATL vs. WAS     W    114                0.0
# 5   Philadelphia 76ers  PHI vs. ATL     L     72                3.0
# 10       Atlanta Hawks  ATL vs. SAC     W    106                2.0
# 14       Atlanta Hawks  ATL vs. LAL     L    116                2.0
# 17  Washington Wizards  WAS vs. ATL     W     95                2.0
#
#     WINS_10GAMES_y WINS_UPTOGAME_y AVGPOINTS_2GAMES_y AVGPOINTS_3GAMES_y  \
# 2              0.0             0.0                NaN                NaN
# 5              0.0             0.0               97.0          97.000000
# 10             2.0             2.0              109.0         109.000000
# 14             3.0             3.0              105.0         108.000000
# 17             0.0             0.0              103.0         101.666667
#
#    AVGPOINTS_4GAMES_y
# 2                 NaN
# 5           97.000000
# 10         109.000000
# 14         108.000000
# 17         101.666667
#
# [5 rows x 27 columns]

# %%
#Create combined points variable
gamelvl_df.loc[:,'TOT_PTS'] = gamelvl_df['PTS_x'] + gamelvl_df['PTS_y']

#Sort by team-date
gamelvl_df = gamelvl_df.sort_values(by=['TEAM_ID_x','GAME_DATE'], ascending=True)

# %%
gamelvl_df.head()
# Out:
#    SEASON_ID   TEAM_ID_x TEAM_ABBREVIATION_x    TEAM_NAME_x     GAME_ID  \
# 5      22016  1610612737                 ATL  Atlanta Hawks  0021600026
# 17     22016  1610612737                 ATL  Atlanta Hawks  0021600070
# 25     22016  1610612737                 ATL  Atlanta Hawks  0021600100
# 37     22016  1610612737                 ATL  Atlanta Hawks  0021600154
# 45     22016  1610612737                 ATL  Atlanta Hawks  0021600174
#
#     GAME_DATE  MATCHUP_x WL_x  PTS_x  DAYS_BTWN_GAMES_x  ...    MATCHUP_y  \
# 5  2016-10-29  ATL @ PHI    W    104                2.0  ...  PHI vs. ATL
# 17 2016-11-04  ATL @ WAS    L     92                2.0  ...  WAS vs. ATL
# 25 2016-11-08  ATL @ CLE    W    110                3.0  ...  CLE vs. ATL
# 37 2016-11-15  ATL @ MIA    W     93                3.0  ...  MIA vs. ATL
# 45 2016-11-18  ATL @ CHA    L     96                2.0  ...  CHA vs. ATL
#
#     WL_y  PTS_y  DAYS_BTWN_GAMES_y  WINS_10GAMES_y  WINS_UPTOGAME_y  \
# 5      L     72                3.0             0.0              0.0
# 17     W     95                2.0             0.0              0.0
# 25     L    106                3.0             6.0              6.0
# 37     L     90                1.0             2.0              2.0
# 45     W    100                3.0             7.0              7.0
#
#    AVGPOINTS_2GAMES_y AVGPOINTS_3GAMES_y AVGPOINTS_4GAMES_y TOT_PTS
# 5                97.0          97.000000          97.000000     176
# 17              103.0         101.666667         101.666667     187
# 25              115.0         119.333333         115.750000     216
# 37               90.5          92.000000          90.250000     183
# 45              104.0         106.333333         105.750000     196
#
# [5 rows x 28 columns]

# %%
#Import and merge distance measure
distances = pd.read_csv("distance_between_cities.csv", keep_default_na=False, na_values=[""])

gamelvl_df = pd.merge(gamelvl_df, distances, on=['TEAM_ABBREVIATION_x', 'TEAM_ABBREVIATION_y'])
gamelvl_df.head(50)
# Out:
#    SEASON_ID   TEAM_ID_x TEAM_ABBREVIATION_
# 43     22018  1610612737                 ATL  Atlanta Hawks  0021800773
# 44     22016  1610612737                 ATL  Atlanta Hawks  0021600252
# 45     22017  1610612737                 ATL  Atlanta Hawks  0021700590
# 46     22018  1610612737                 ATL  Atlanta Hawks  0021800189
# 47     22016  1610612737                 ATL  Atlanta Hawks  0021600259
# 48     22017  1610612737                 ATL  Atlanta Hawks  0021701087
# 49     22018  1610612737                 ATL  Atlanta Hawks  0021800201
#
#     GAME_DATE  MATCHUP_x WL_x  PTS_x  DAYS_BTWN_GAMES_x  ...  \
# 0  2016-10-29  ATL @ PHI    W    104                2.0  ...
# 1  2017-03-29  ATL @ PHI    W     99                1.0  ...
# 2  2017-11-01  ATL @ PHI    L    109                3.0  ...
# 3  2018-10-29  ATL @ PHI    L     92                2.0  ...
# 4  2019-01-11  ATL @ PHI    W    123                2.0  ...
# 5  2016-11-04  ATL @ WAS    L     92                2.0  ...
# 6  2017-03-22  ATL @ WAS    L    100                2.0  ...
# 7  2017-11-11  ATL @ WAS    L     94                1.0  ...
# 8  2018-04-06  ATL @ WAS    W    103                2.0  ...
# 9  2019-01-02  ATL @ WAS    L     98                2.0  ...
# 10 2019-02-04  ATL @ WAS    W    137                2.0  ...
# 11 2016-11-08  ATL @ CLE    W    110                3.0  ...
# 12 2017-04-07  ATL @ CLE    W    114                1.0  ...
# 13 2017-11-05  ATL @ CLE    W    117                2.0  ...
# 14 2017-12-12  ATL @ CLE    L    114                2.0  ...
# 15 2018-10-21  ATL @ CLE    W    133                2.0  ...
# 16 2018-10-30  ATL @ CLE    L    114                1.0  ...
# 17 2016-11-15  ATL @ MIA    W     93                3.0  ...
# 18 2017-02-01  ATL @ MIA    L     93                3.0  ...
# 19 2017-10-23  ATL @ MIA    L     93                1.0  ...
# 20 2018-04-03  ATL @ MIA    L     98                2.0  ...
# 21 2018-11-27  ATL @ MIA    W    115                2.0  ...
# 22 2019-03-04  ATL @ MIA    L    113                1.0  ...
# 23 2016-11-18  ATL @ CHA    L     96                2.0  ...
# 24 2017-03-20  ATL @ CHA    L     90                2.0  ...
# 25 2017-10-20  ATL @ CHA    L     91                2.0  ...
# 26 2018-01-26  ATL @ CHA    L    110                2.0  ...
# 27 2018-11-06  ATL @ CHA    L    102                3.0  ...
# 28 2018-11-28  ATL @ CHA    L     94                1.0  ...
# 29 2016-11-20  ATL @ NYK    L     94                2.0  ...
# 30 2017-01-16  ATL @ NYK    W    108                1.0  ...
# 31 2017-12-10  ATL @ NYK    L    107                1.0  ...
# 32 2018-02-04  ATL @ NYK    W     99                2.0  ...
# 33 2018-10-17  ATL @ NYK    L    107                0.0  ...
# 34 2018-12-21  ATL @ NYK    W    114                3.0  ...
# 35 2016-11-23  ATL @ IND    W     96                1.0  ...
# 36 2017-04-12  ATL @ IND    L     86                1.0  ...
# 37 2018-02-23  ATL @ IND    L     93                9.0  ...
# 38 2018-03-09  ATL @ IND    L     87                3.0  ...
# 39 2018-11-17  ATL @ IND    L     89                2.0  ...
# 40 2018-12-31  ATL @ IND    L    108                2.0  ...
# 41 2016-11-25  ATL @ UTA    L     68                2.0  ...
# 42 2018-03-20  ATL @ UTA    W     99                3.0  ...
# 43 2019-02-01  ATL @ UTA    L    112                2.0  ...
# 44 2016-11-27  ATL @ LAL    L     94                2.0  ...
# 45 2018-01-07  ATL @ LAL    L    113                2.0  ...
# 46 2018-11-11  ATL @ LAL    L    106                2.0  ...
# 47 2016-11-28  ATL @ GSW    L    100                1.0  ...
# 48 2018-03-23  ATL @ GSW    L     94                1.0  ...
# 49 2018-11-13  ATL @ GSW    L    103                2.0  ...
#
#     DAYS_BTWN_GAMES_y  WINS_10GAMES_y  WINS_UPTOGAME_y  AVGPOINTS_2GAMES_y  \
# 0                 3.0             0.0              0.0                97.0
# 1                 1.0             5.0             28.0               100.0
# 2                 2.0             3.0              3.0               113.5
# 3                 2.0             3.0              3.0               106.5
# 4                 2.0             7.0             27.0               119.0
# 5                 2.0             0.0              0.0               103.0
# 6                 2.0             6.0             42.0                97.5
# 7                 2.0             5.0              6.0               105.0
# 8                 1.0             3.0             42.0               109.5
# 9                 4.0             3.0             14.0               111.0
# 10                2.0             5.0             22.0               111.0
# 11                3.0             6.0              6.0               115.0
# 12                2.0             6.0             51.0               118.0
# 13                2.0             4.0              4.0               118.5
# 14                3.0             9.0             19.0               103.5
# 15                2.0             0.0              0.0               113.5
# 16                3.0             0.0              0.0               105.0
# 17                1.0             2.0              2.0                90.5
# 18                2.0             8.0             19.0               110.0
# 19                2.0             1.0              1.0               110.5
# 20                3.0             5.0             41.0               106.0
# 21                2.0             3.0              7.0               109.0
# 22                2.0             3.0             28.0               117.5
# 23                3.0             7.0              7.0               104.0
# 24                2.0             5.0             30.0                87.5
# 25                2.0             0.0              0.0                90.0
# 26                2.0             6.0             19.0               104.0
# 27                3.0             5.0              5.0               116.5
# 28                2.0             5.0             10.0               116.5
# 29                3.0             4.0              5.0               108.5
# 30                1.0             2.0             18.0               102.5
# 31                1.0             4.0             12.0               100.5
# 32                2.0             4.0             23.0                81.5
# 33                0.0             0.0              0.0                 NaN
# 34                2.0             2.0              9.0               109.5
# 35                2.0             5.0              7.0                99.0
# 36                2.0             5.0             41.0               123.5
# 37                9.0             7.0             33.0               114.5
# 38                2.0             7.0             37.0                88.0
# 39                1.0             6.0              9.0               101.0
# 40                3.0             8.0             24.0               127.0
# 41                2.0             5.0              8.0                99.5
# 42                3.0             9.0             40.0               109.5
# 43                2.0             8.0             29.0               115.0
# 44                2.0             4.0              8.0                95.5
# 45                2.0             1.0             11.0                95.0
# 46                1.0             6.0              6.0               107.5
# 47                2.0            10.0             15.0               112.0
# 48                4.0             6.0             53.0                99.5
# 49                1.0             8.0             11.0               116.0
#
#     AVGPOINTS_3GAMES_y  AVGPOINTS_4GAMES_y TOT_PTS         origin  \
# 0            97.000000           97.000000     176  Atlanta Hawks
# 1           105.666667          103.500000     191  Atlanta Hawks
# 2           110.333333          107.000000     228  Atlanta Hawks
# 3           115.000000          115.250000     205  Atlanta Hawks
# 4           114.666667          119.000000     244  Atlanta Hawks
# 5           101.666667          101.666667     187  Atlanta Hawks
# 27             Charlotte         243.69
# 28             Charlotte         243.69
# 29  New York (Manhattan)         864.61
# 30  New York (Manhattan)         864.61
# 31  New York (Manhattan)         864.61
# 32  New York (Manhattan)         864.61
# 33  New York (Manhattan)         864.61
# 34  New York (Manhattan)         864.61
# 35          Indianapolis         533.54
# 36          Indianapolis         533.54
# 37          Indianapolis         533.54
# 38          Indianapolis         533.54
# 39          Indianapolis         533.54
# 40          Indianapolis         533.54
# 41        Salt Lake City        1872.01
# 42        Salt Lake City        1872.01
# 43        Salt Lake City        1872.01
# 44           Los Angeles        2178.97
# 45           Los Angeles        2178.97
# 46           Los Angeles        2178.97
# 47               Oakland        2456.90
# 48               Oakland        2456.90
# 49               Oakland        2456.90
#
# [50 rows x 31 columns]

# %%
# Import & Merge Rivalry info
rivalries = pd.read_csv("rivalries.csv", keep_default_na=True, na_values=[""])
gamelvl_df = pd.merge(gamelvl_df, rivalries, how="outer", on=['TEAM_ABBREVIATION_x', 'TEAM_ABBREVIATION_y']).fillna(0)

# %%
gamelvl_df = gamelvl_df.drop(columns=['origin','destination','Team A','Team B'])

gamelvl_df.head()
# Out:
#   SEASON_ID   TEAM_ID_x TEAM_ABBREVIATION_x    TEAM_NAME_x     GAME_ID  \
# 0     22016  1610612737                 ATL  Atlanta Hawks  0021600026
# 1     22016  1610612737                 ATL  Atlanta Hawks  0021601111
# 2     22017  1610612737                 ATL  Atlanta Hawks  0021700107
# 3     22018  1610612737                 ATL  Atlanta Hawks  0021800088
# 4     22018  1610612737                 ATL  Atlanta Hawks  0021800621
#
#    GAME_DATE  MATCHUP_x WL_x  PTS_x  DAYS_BTWN_GAMES_x  ...  PTS_y  \
# 0 2016-10-29  ATL @ PHI    W    104                2.0  ...     72
# 1 2017-03-29  ATL @ PHI    W     99                1.0  ...     92
# 2 2017-11-01  ATL @ PHI    L    109                3.0  ...    119
# 3 2018-10-29  ATL @ PHI    L     92                2.0  ...    113
# 4 2019-01-11  ATL @ PHI    W    123                2.0  ...    121
#
#    DAYS_BTWN_GAMES_y  WINS_10GAMES_y  WINS_UPTOGAME_y  AVGPOINTS_2GAMES_y  \
# 0                3.0             0.0              0.0                97.0
# 1                1.0             5.0             28.0               100.0
# 2                2.0             3.0              3.0               113.5
# 3                2.0             3.0              3.0               106.5
# 4                2.0             7.0             27.0               119.0
#
#    AVGPOINTS_3GAMES_y AVGPOINTS_4GAMES_y TOT_PTS distance_miles rivalry
# 0           97.000000              97.00     176         775.82     0.0
# 1          105.666667             103.50     191         775.82     0.0
# 2          110.333333             107.00     228         775.82     0.0
# 3          115.000000             115.25     205         775.82     0.0
# 4          114.666667             119.00     244         775.82     0.0
#
# [5 rows x 30 columns]

# %%
#Add combined points of previous matchup
gamelvl_df['pre_PTS'] = gamelvl_df.groupby('MATCHUP_x')['TOT_PTS'].shift(1)

gamelvl_df.head(20)
# Out:
#    SEASON_ID   TEAM_ID_x TEAM_ABBREVIATION_x    TEAM_NAME_x     GAME_ID  \
# 0      22016  1610612737                 ATL  Atlanta Hawks  0021600026
# 1      22016  1610612737                 ATL  Atlanta Hawks  0021601111
# 2      22017  1610612737                 ATL  Atlanta Hawks  0021700107
# 3      22018  1610612737                 ATL  Atlanta Hawks  0021800088
# 4      22018  1610612737                 ATL  Atlanta Hawks  0021800621
# 5      22016  1610612737                 ATL  Atlanta Hawks  0021600070
# 6      22016  1610612737                 ATL  Atlanta Hawks  0021601063
# 7      22017  1610612737                 ATL  Atlanta Hawks  0021700177
# 8      22017  1610612737                 ATL  Atlanta Hawks  0021701184
# 9      22018  1610612737                 ATL  Atlanta Hawks  0021800556
# 10     22018  1610612737                 ATL  Atlanta Hawks  0021800791
# 11     22016  1610612737                 ATL  Atlanta Hawks  0021600100
# 12     22016  1610612737                 ATL  Atlanta Hawks  0021601179
# 13     22017  1610612737                 ATL  Atlanta Hawks  0021700136
# 14     22017  1610612737                 ATL  Atlanta Hawks  0021700397
# 15     22018  1610612737                 ATL  Atlanta Hawks  0021800036
# 16     22018  1610612737                 ATL  Atlanta Hawks  0021800097
# 17     22016  1610612737                 ATL  Atlanta Hawks  0021600154
# 18     22016  1610612737                 ATL  Atlanta Hawks  0021600734
# 19     22017  1610612737                 ATL  Atlanta Hawks  0021700042
#
#     GAME_DATE  MATCHUP_x WL_x  PTS_x  DAYS_BTWN_GAMES_x  ...  \
# 0  2016-10-29  ATL @ PHI    W    104                2.0  ...
# 1  2017-03-29  ATL @ PHI    W     99                1.0  ...
# 2  2017-11-01  ATL @ PHI    L    109                3.0  ...
# 3  2018-10-29  ATL @ PHI    L     92                2.0  ...
# 4  2019-01-11  ATL @ PHI    W    123                2.0  ...
# 5  2016-11-04  ATL @ WAS    L     92                2.0  ...
# 6  2017-03-22  ATL @ WAS    L    100                2.0  ...
# 7  2017-11-11  ATL @ WAS    L     94                1.0  ...
# 8  2018-04-06  ATL @ WAS    W    103                2.0  ...
# 9  2019-01-02  ATL @ WAS    L     98                2.0  ...
# 10 2019-02-04  ATL @ WAS    W    137                2.0  ...
# 11 2016-11-08  ATL @ CLE    W    110                3.0  ...
# 12 2017-04-07  ATL @ CLE    W    114                1.0  ...
# 13 2017-11-05  ATL @ CLE    W    117                2.0  ...
# 14 2017-12-12  ATL @ CLE    L    114                2.0  ...
# 15 2018-10-21  ATL @ CLE    W    133                2.0  ...
# 16 2018-10-30  ATL @ CLE    L    114                1.0  ...
# 17 2016-11-15  ATL @ MIA    W     93                3.0  ...
# 18 2017-02-01  ATL @ MIA    L     93                3.0  ...
# 19 2017-10-23  ATL @ MIA    L     93                1.0  ...
#
#     DAYS_BTWN_GAMES_y  WINS_10GAMES_y  WINS_UPTOGAME_y  AVGPOINTS_2GAMES_y  \
# 0                 3.0             0.0              0.0                97.0
# 1                 1.0             5.0             28.0               100.0
# 2                 2.0             3.0              3.0               113.5
# 3                 2.0             3.0              3.0               106.5
# 4                 2.0             7.0             27.0               119.0
# 5                 2.0             0.0              0.0               103.0
# 6                 2.0             6.0             42.0                97.5
# 7                 2.0             5.0              6.0               105.0
# 8                 1.0             3.0             42.0               109.5
# 9                 4.0             3.0             14.0               111.0
# 10                2.0             5.0             22.0               111.0
# 11                3.0             6.0              6.0               115.0
# 12                2.0             6.0             51.0               118.0
# 13                2.0             4.0              4.0               118.5
# 14                3.0             9.0             19.0               103.5
# 15                2.0             0.0              0.0               113.5
# 16                3.0             0.0              0.0               105.0
# 17                1.0             2.0              2.0                90.5
# 18                2.0             8.0             19.0               110.0
# 19                2.0             1.0              1.0               110.5
#
#     AVGPOINTS_3GAMES_y  AVGPOINTS_4GAMES_y TOT_PTS distance_miles rivalry  \
# 0            97.000000           97.000000     176         775.82     0.0
# 1           105.666667          103.500000     191         775.82     0.0
# 2           110.333333          107.000000     228         775.82     0.0
# 3           115.000000          115.250000     205         775.82     0.0
# 4           114.666667          119.000000     244         775.82     0.0
# 5           101.666667          101.666667     187         636.35     0.0
# 6           102.333333          103.500000     204         636.35     0.0
# 7           105.666667          109.750000     207         636.35     0.0
# 8           104.333333          105.000000     200         636.35     0.0
# 9           105.666667          101.500000     212         636.35     0.0
# 10          111.666667          113.500000     266         636.35     0.0
# 11          119.333333          115.750000     216         708.26     0.0
# 12          123.666667          123.250000     214         708.26     0.0
# 13          110.666667          108.250000     232         708.26     0.0
# 14          102.666667          105.250000     237         708.26     0.0
# 15          113.500000          113.500000     244         708.26     0.0
# 16           98.666667          101.750000     250         708.26     0.0
# 17           92.000000           90.250000     183         662.37     0.0
# 18          106.666667          107.250000     209         662.37     0.0
# 19          110.500000          110.500000     197         662.37     0.0
#
#    pre_PTS
# 0      NaN
# 1    176.0
# 2    191.0
# 3    228.0
# 4    205.0
# 5      NaN
# 6    187.0
# 7    204.0
# 8    207.0
# 9    200.0
# 10   212.0
# 11     NaN
# 12   216.0
# 13   214.0
# 14   232.0
# 15   237.0
# 16   244.0
# 17     NaN
# 18   183.0
# 19   209.0
#
# [20 rows x 31 columns]

# %%
#Getting referee information for each of the games & combining into one dataset
#NOTE: This code takes FOREVER to run.

for i in final_games_data.GAME_ID:
    temp = boxscoresummaryv2.BoxScoreSummaryV2(game_id=i)   
    games_ref_temp = temp.officials.get_data_frame()
    games_ref_temp['GAME_ID'] = i
    games_ref = games_ref.append(games_ref_temp)

# %%
games_ref.head(20)
# Out:
#    OFFICIAL_ID FIRST_NAME     LAST_NAME JERSEY_NUM     GAME_ID
# 0         1199        Tom    Washington       49    0021801230
# 1       202027        Tre        Maddox       73    0021801230
# 2      1626300        Ray        Acosta       54    0021801230
# 0         1199        Tom    Washington       49    0021801230
# 1       202027        Tre        Maddox       73    0021801230
# 2      1626300        Ray        Acosta       54    0021801230
# 0         1195    Derrick      Stafford       9     0021600026
# 1         2004   Courtney      Kirkland       61    0021600026
# 2       201246      Kevin        Cutler       34    0021600026
# 0         1198      Scott          Wall       31    0021601111
# 1       101284       John         Goble       30    0021601111
# 2       202056         CJ    Washington       53    0021601111
# 0         1662       Bill       Kennedy       55    0021700107
# 1       201246      Kevin        Cutler       34    0021700107
# 2       201637   Haywoode       Workman       66    0021700107
# 0       101284       John         Goble       30    0021800088
# 1       202041      Kevin         Scott       28    0021800088
# 2      1628953     Ashley  Moyer-Gleich       75    0021800088
# 0         1193    Michael         Smith       38    0021800621
# 1       201639       Josh         Tiven       58    0021800621

# %%
#First game is duplicated - fix that
games_ref2 = games_ref.drop_duplicates()
games_ref2.head()
# Out:
#    OFFICIAL_ID FIRST_NAME   LAST_NAME JERSEY_NUM     GAME_ID
# 0         1199        Tom  Washington       49    0021801230
# 1       202027        Tre      Maddox       73    0021801230
# 2      1626300        Ray      Acosta       54    0021801230
# 0         1195    Derrick    Stafford       9     0021600026
# 1         2004   Courtney    Kirkland       61    0021600026

# %%
#Export referee information to a csv file so that we can directly pull from that
#Rather than having to re-run the above code every time

games_ref2.to_csv('referees.csv')

# %%
#Use if importing referee info rather than going through the prior commands
games_ref2 = pd.read_csv('referees.csv')
games_ref2 = games_ref2.drop(columns=['Unnamed: 0'])
games_ref2.head()
# Out:
#    OFFICIAL_ID FIRST_NAME   LAST_NAME  JERSEY_NUM   GAME_ID
# 0         1199        Tom  Washington          49  21801230
# 1       202027        Tre      Maddox          73  21801230
# 2      1626300        Ray      Acosta          54  21801230
# 3         1195    Derrick    Stafford           9  21600026
# 4         2004   Courtney    Kirkland          61  21600026

# %%
#Merge referee data in to create final dataset
#Note that as it currently stands, each game has multiple (3) rows because there are multiple (3) referees per game

gamelvl_df['GAME_ID'] = gamelvl_df['GAME_ID'].astype(int)

final_nba_data = pd.merge(gamelvl_df, games_ref2, how="outer", on=['GAME_ID'])
final_nba_data = final_nba_data.sort_values(by=['SEASON_ID','GAME_DATE'], ascending=True)
final_nba_data.head()
# Out:
#      SEASON_ID   TEAM_ID_x TEAM_ABBREVIATION_x        TEAM_NAME_x   GAME_ID  \
# 5535     22016  1610612752                 NYK    New York Knicks  21600001
# 5536     22016  1610612752                 NYK    New York Knicks  21600001
# 5537     22016  1610612752                 NYK    New York Knicks  21600001
# 8119     22016  1610612759                 SAS  San Antonio Spurs  21600003
# 8120     22016  1610612759                 SAS  San Antonio Spurs  21600003
#
#       GAME_DATE  MATCHUP_x WL_x  PTS_x  DAYS_BTWN_GAMES_x  ...  \
# 5535 2016-10-25  NYK @ CLE    L     88                0.0  ...
# 5536 2016-10-25  NYK @ CLE    L     88                0.0  ...
# 5537 2016-10-25  NYK @ CLE    L     88                0.0  ...
# 8119 2016-10-25  SAS @ GSW    W    129                0.0  ...
# 8120 2016-10-25  SAS @ GSW    W    129                0.0  ...
#
#       AVGPOINTS_3GAMES_y  AVGPOINTS_4GAMES_y  TOT_PTS  distance_miles  \
# 5535                 0.0                 0.0      205          462.99
# 5536                 0.0                 0.0      205          462.99
# 5537                 0.0                 0.0      205          462.99
# 8119                 0.0                 0.0      229         1721.11
# 8120                 0.0                 0.0      229         1721.11
#
#       rivalry  pre_PTS OFFICIAL_ID FIRST_NAME LAST_NAME JERSEY_NUM
# 5535      0.0      NaN        1363     Bennie     Adams         47
# 5536      0.0      NaN        1662       Bill   Kennedy         55
# 5537      0.0      NaN      202026       Karl      Lane         77
# 8119      0.0      NaN        1152        Dan  Crawford         43
# 8120      0.0      NaN        2003        Pat    Fraher         26
#
# [5 rows x 35 columns]

# %%
#Export final dataset to csv so that a separate Jupyter notebook can be used
#for creating the model
final_nba_data.to_csv('final_nba_data.csv')
